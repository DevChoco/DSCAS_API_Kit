# %%
# !pip install "ray[tune]"
# Out:
# Requirement already satisfied: ray[tune] in c:\users\user\anaconda3\envs\dscas\lib\site-packages (2.44.1)
# Requirement already satisfied: click>=7.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (8.1.8)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (3.18.0)
# Requirement already satisfied: jsonschema in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (1.1.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (6.30.2)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (6.0.2)
# Requirement already satisfied: aiosignal in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (1.3.2)
# Requirement already satisfied: frozenlist in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (1.5.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (2.2.3)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (19.0.1)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ray[tune]) (2025.3.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from click>=7.0->ray[tune]) (0.4.6)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from tensorboardX>=1.9->ray[tune]) (2.2.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from jsonschema->ray[tune]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from jsonschema->ray[tune]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from jsonschema->ray[tune]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from jsonschema->ray[tune]) (0.24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->ray[tune]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->ray[tune]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->ray[tune]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->ray[tune]) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from referencing>=0.28.4->jsonschema->ray[tune]) (4.13.2)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\envs\dscas\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from opencv-python) (2.2.4)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\dscas\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\envs\dscas\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-learn) (2.2.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-learn) (3.6.0)

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\user\anaconda3\envs\dscas\lib\site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (2.2.4)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (2025.3.30)
# Requirement already satisfied: packaging>=21 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from scikit-image) (0.4)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\dscas\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from tqdm) (0.4.6)

# %%
# !pip install open_clip_torch
# Out:
# Requirement already satisfied: open_clip_torch in c:\users\user\anaconda3\envs\dscas\lib\site-packages (2.32.0)
# Requirement already satisfied: torch>=1.9.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (2.6.0)
# Requirement already satisfied: torchvision in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (0.21.0)
# Requirement already satisfied: regex in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (2024.11.6)
# Requirement already satisfied: ftfy in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (6.3.1)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (0.30.2)
# Requirement already satisfied: safetensors in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (0.5.3)
# Requirement already satisfied: timm in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from open_clip_torch) (1.0.15)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torch>=1.9.0->open_clip_torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torch>=1.9.0->open_clip_torch) (4.13.2)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torch>=1.9.0->open_clip_torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torch>=1.9.0->open_clip_torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torch>=1.9.0->open_clip_torch) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torch>=1.9.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from sympy==1.13.1->torch>=1.9.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from huggingface-hub->open_clip_torch) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from huggingface-hub->open_clip_torch) (6.0.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from huggingface-hub->open_clip_torch) (2.32.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from tqdm->open_clip_torch) (0.4.6)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torchvision->open_clip_torch) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from torchvision->open_clip_torch) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\dscas\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2025.1.31)

# %%
import torch
from PIL import Image
from pipeline import pipeline, segmentation_filter, user_palette_classification_filter, retrieval_filter
from utils import segmentation_labels, utils
import matplotlib.pyplot as plt
from palette_classification import color_processing, palette
import glob
import json
import os

# %%
# demo config
input_filename = 'aaaa.jpg' # 사람이미지
device = 'cuda' if torch.cuda.is_available() else 'cpu'
verbose = False
segmentation_model = 'cloud' # should be in ['local', 'cloud']
query = 'upper_body' # should be in ['dress', 'upper_body', 'lower_body']
n_plotted_retrieved_clothes = 10

# %%
# setting paths
palettes_path = 'palette_classification/palettes/'
cloth_dataset_path = 'dresscode_test_dataset/'
palette_mappings_path = 'palette_classification/clothing_palette_mappings/'

# loading reference palettes for user palette classification filter
palette_filenames = glob.glob(palettes_path + '*.csv')
reference_palettes = [palette.PaletteRGB().load(
    palette_filename.replace('\\', '/'), header=True) for palette_filename in palette_filenames]

# loading palette mappings for retrieval filter
palette_mappings_dict = {}
for category in ['dresses','lower_body', 'upper_body']: #lower_body 'dresses','lower_body', 제외
    mapping_dict_filename = palette_mappings_path + category + '/' + category + '_palette_mappings.json'
    with open(mapping_dict_filename) as mapping_dict_file:
        palette_mappings_dict[category] = json.load(mapping_dict_file)

# instantiating pipeline
pl = pipeline.Pipeline()

# %%
# loading input image
input = Image.open(input_filename).convert('RGB')
input
# Out:
# <PIL.Image.Image image mode=RGB size=640x700>

# %%
# adding segmentation filter
sf = segmentation_filter.SegmentationFilter(segmentation_model)
pl.add_filter(sf)

# %%
# executing pipeline: sf
img, masks = pl.execute(input, device, verbose)
img_segmented = color_processing.colorize_segmentation_masks(masks, segmentation_labels.labels)

# %%
# showing output of pipeline: sf
plt.figure(figsize=(20, 12))
plt.subplot(1, 2, 1)
plt.imshow(utils.from_DHW_to_HWD(img))
plt.subplot(1, 2, 2)
plt.imshow(utils.from_DHW_to_HWD(img_segmented))

# %%
# adding user palette classification filter
upcf = user_palette_classification_filter.UserPaletteClassificationFilter(reference_palettes)
pl.add_filter(upcf)

# %%
# executing pipeline: sf -> upcf
user_palette = pl.execute(input, device, verbose)

# %%
# # showing output of pipeline: sf -> upcf
print(user_palette.description())
user_palette.plot(tile_size=15)
# Out:
# summer

# %%
#============

# %%
# adding retrieval filter
rf = retrieval_filter.RetrievalFilter(cloth_dataset_path, palette_mappings_dict)
rf.set_query(query)
pl.add_filter(rf)

# %%
# executing pipeline: sf -> upcf -> rf
retrieved_clothes_paths = pl.execute(input, device, verbose)
n_retrieved_clothes = len(retrieved_clothes_paths)
print(f'Found {n_retrieved_clothes} clothes for query "{query}" and palette "{user_palette.description()}".')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:03<00:00,  1.79it/s]
# Found 52 clothes for query "upper_body" and palette "summer".

# %%
i = 1
n_columns = min(n_plotted_retrieved_clothes, 5)
n_rows = (n_plotted_retrieved_clothes + n_columns - 1) // n_columns  # 나머지 존재 시 한 줄 추가
print(f'Showing first {n_plotted_retrieved_clothes} retrieved clothes.')
plt.figure(figsize=(20, 5 * n_rows))

for c in range(1, n_columns + 1):
    for r in range(1, n_rows + 1):
        if i > n_plotted_retrieved_clothes:
            break
        plt.subplot(n_rows, n_columns, i)
        img_path = retrieved_clothes_paths[i-1]
        img = Image.open(img_path).convert('RGB')
        plt.imshow(img)
        plt.axis('off')
        
        filename = os.path.basename(img_path)
        plt.title(filename, fontsize=12)
        
        i += 1
# Out:
# Showing first 10 retrieved clothes.
